# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/bosch/MLOps2/.git/

# %%
# !git add .gitignore

# %%
# !git commit -m "Primer Commit"
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	MLOps2.code-workspace
# 	MynewMLOps.ipynb
# 	archivo1.txt
# 	archivo2.txt
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git remote -v
# Out:
# origin	git@github.com:andreuet1/MLOps2.git (fetch)
# origin	git@github.com:andreuet1/MLOps2.git (push)

# %%
# !git remote set-url origin https://github.com/andreuet1/MLOps2.git

# %%
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/andreuet1/MLOps2.git
#  * [new branch]      main -> main

# %%
# !git remote add origin git@github.com:andreuet1/MLOps2.git

# %%
# !git branch -M main
